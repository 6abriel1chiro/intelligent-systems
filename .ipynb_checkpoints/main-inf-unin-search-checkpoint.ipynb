# %% [markdown]
# # Assignment 1: Find a path from the start to the goal

# %% [markdown]
# This assignment is worth 15/100 points.
#
# You need to do this assignment with a group of maximum 3 people in total.
#
# You will program path-finding algorithms using informed and uninformed search and compare them. You will need to implement the following algorithms:
#
# Uninformed Search:
# - BFS
# - DFS
#
# Informed Search:
# - A*
#
# Answer to all the questions in english, argument, and justify your answers using the obtained results.
#
# ### Deadline
# March 3th, 2023 at 23.59
#
# ### Some Instructions
# - You need to fill in your answers here and submit this jupyter notebook via NEO.
# - It should run smoothly.
# - Any compilation error will affect your total score.
#
#
# ### Important before starting!
#
# - DO NOT copy the answers from internet nor from your classmates.
# - If there are two or more groups that were discovered cheeting, then they will be penalized with 0/15.
# - Use your brain and the material seen in class to program this assignment.
# - You should be able to explain and modify your code according to your (or my) needs.

# %% [markdown]
# ### Names
# You and your classmate names:
# - Gabriel Ichiro Balderrama Vargas
# - Rodrigo Guardia
# - Angy Encinas

# %% [markdown]
# ## Code for drawing the map

# %% [markdown]
# The following code will help you draw the map. You don't need to modify it.

# %% [markdown]
# #### Import libraries

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
from queue import Queue
from queue import LifoQueue
from queue import PriorityQueue
import math

# %% [markdown]
# #### Read map from file and define where the start and goal positions are

# %%
map_file = "map1.txt"
start_char = '1'
goal_char = '4'
tree_char = '2'
water_char = '3'
visited_char = '5'

def read_map_file(file_name = "map1.txt"):
    i = 0
    j = 0
    my_map = []
    start = [0,0]
    goal  = [0,0]
    with open(file_name) as f:
        lines = f.readlines()
        for line in lines:
            line_arr = []
            j = 0
            for char in line:
                # skip carry char
                if char != '\n':
                    line_arr.append(int(char))
                # start char is 1
                if char == start_char:
                    start = [j, i]
                # end char is 3
                if char == goal_char:
                    goal = [j, i]

                j += 1
            my_map.append(line_arr)
            i += 1
        return my_map, start, goal

my_map, start, goal = read_map_file()
print('Start at:', start)
print('Goal at:', goal)
# Out:
# Start at: [2, 6]
# Goal at: [16, 2]

# %% [markdown]
# #### Draw the map

# %%
# inspired by: https://stackoverflow.com/questions/38973868/adjusting-gridlines-and-ticks-in-matplotlib-imshow
def draw_map(my_map, path = []):
    xlen = len(my_map[0])
    ylen = len(my_map)
    colormap = colors.ListedColormap(["white","yellow",'lightgreen', 'cyan', 'red', 'pink'])
    
    # set ticks top and bottom
    plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
    plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
    
    plt.figure()
    im = plt.imshow(my_map, cmap = colormap)
    ax = plt.gca()

    # Major ticks
    ax.set_xticks(np.arange(0, xlen, 1))
    ax.set_yticks(np.arange(0, ylen, 1))

    # Labels for major ticks
    ax.set_xticklabels(np.arange(0, xlen, 1))
    ax.set_yticklabels(np.arange(0, ylen, 1))

    # Minor ticks
    ax.set_xticks(np.arange(-.5, xlen, 1), minor=True)
    ax.set_yticks(np.arange(-.5, ylen, 1), minor=True)

    # Gridlines based on minor ticks
    ax.grid(which='minor', color='grey', linestyle='-', linewidth=2)
    
    for step in path:
        plt.plot(step[0], step[1], marker='o', color='b')
        
    ax.text(start[0]-0.3, start[1]+ 0.3, 'S', fontsize=13)
    ax.text(goal[0]-0.3, goal[1]+ 0.3, 'G', fontsize=13)

    plt.show()

# %% [markdown]
# ## Exercise Problem-Solver Agent

# %% [markdown]
# 1. What is an Agent?

# %%
# here your answer

# %% [markdown]
# 2. What is a Problem-Solver Agent? Define a problem-solver agent to find the path between two points in a map.

# %%
# here your answer

# %% [markdown]
# ## Exercise Uninformed Search

# %% [markdown]
# #### color code:
#
# Here is what every element in the map means:
#
# - white (0):   blank space
# - yellow (1):  starting position
# - green (2):   trees
# - cyan (3):    water
# - red (4):     goal position
# - brown (5):  expanded state (already visited)
#
#
# For uninformed search let's suppose:
# - the agent can't go through trees nor water (they are obstacles).
# - the cost to go from one state to another is 1.

# %% [markdown]
# #### BFS
#
# 1. Implement BFS algorithm to find the path between start and goal. To help you out with this task you can complete the code below using what we have seen in class.

# %%
actions = ['U', 'D', 'L', 'R']
cost = 0

class State:
    def __init__(self):
        self.father = None
        self.value = None

def get_path(state, path):
    if (state.father != None):
        path.append(state.value)
        get_path(state.father, path)
        return path, len(path)

def goal_test(state, goal):
    if state == goal:return True
    return False

def tf(state, action, my_map):
    x = state.value[0]
    y = state.value[1]
    limit_x = len(my_map[0]) - 1
    limit_y = len(my_map) - 1
    next_state = None
    
    if action == 'L' and x > 0:
        next_state =  [x-1, y]
    elif action == 'R' and x < limit_x:
        next_state = [x+1, y]
    elif action == 'U' and y > 0:
        next_state = [x, y-1]
    elif action == 'D' and y < limit_y:
        next_state = [x, y+1]
    
    if next_state is not None:
        # verify if we already visited that state
        if my_map[next_state[1]][next_state[0]] != 5 and my_map[next_state[1]][next_state[0]] != 2 and  my_map[next_state[1]][next_state[0]] != 3:
            new_state = State()
            new_state.father = state
            new_state.value = next_state
            return True, new_state
        
    return False, _

def bfs(start, goal, actions, my_map):
    start_state = State()
    start_state.value = start
    open_states = Queue()
    open_states.put(start_state)
    
    while not open_states.empty():
        state = open_states.get()
        my_map[state.value[1]][state.value[0]] = int(visited_char)
        
        if (goal_test(state.value, goal)):
            return (True, state)
        
        for action in actions:
            succesor, new_state = tf(state, action, my_map)
            if (succesor == True):
                open_states.put(new_state)
        
    return False, _

# %%
my_map, start, goal = read_map_file()
found, goal_state = bfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1# restore start position  color
print('Solution found? ', found)
p = []
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
print(cost)
# Out:
# Solution found?  True
# 29

# %% [markdown]
# #### DFS
#
# 1. Implement DFS algorithm to find the path between start and goal.

# %%
actions = ['U', 'D', 'L', 'R']
path_taken=[]

class State:
    def __init__(self):
        self.father = None
        self.value = None

def get_path(state, path):
    if (state.father != None):
        path.append(state.value)
        get_path(state.father, path)
        return path, len(path)

def goal_test(state, goal):
    if state == goal:return True
    return False

def cost_function():
    return len(path_taken)

def tf(state, action, my_map):
    x = state.value[0]
    y = state.value[1]
    limit_x = len(my_map[0]) - 1
    limit_y = len(my_map) - 1
    next_state = None
    if action == 'L' and x > 0:
        next_state =  [x-1, y]
    elif action == 'R' and x < limit_x:
        next_state = [x+1, y]
    elif action == 'U' and y > 0:
        next_state = [x, y-1]
    elif action == 'D' and y < limit_y:
        next_state = [x, y+1]
    
    if next_state is not None:
        # verify if we already visited that state
        if my_map[next_state[1]][next_state[0]] != 5 and my_map[next_state[1]][next_state[0]] != 2 and  my_map[next_state[1]][next_state[0]] != 3 :
            new_state = State()
            new_state.father = state
            new_state.value = next_state
            return True, new_state
        
    return False, _

def dfs(start, goal, actions, my_map):
    start_state = State()
    start_state.value = start
    open_states = LifoQueue()
    open_states.put(start_state)
    possible_states = 0
    
    while not open_states.empty():
        state = open_states.get()
        my_map[state.value[1]][state.value[0]] = int(visited_char)
        
        if (goal_test(state.value, goal)):
            print(possible_states)
            return (True, state)
        
        for action in actions:
            succesor, new_state = tf(state, action, my_map)
            if (succesor == True):
                open_states.put(new_state)
                possible_states +=1
        
        
    return False, _

# %%
my_map, start, goal = read_map_file()
found, goal_state = dfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# 262
# Solution found?  True

# %% [markdown]
# 2. Now change the order of the actions. Do you have a shorter path (hint: to answer this, calculate the cost of the path and experiment with diferent order for the actions)? Why is that?

# %%
# your code here
list_of_actions = [['L', 'D', 'R', 'U'], ['D', 'U', 'L', 'R'], ['U', 'R', 'D', 'L']]
#DFS
for actions in list_of_actions:
    my_map, start, goal = read_map_file()
    found, goal_state = dfs(start, goal, actions, my_map)
    my_map[start[1]][start[0]] = 1
    print('Solution found? ', found)
    if found:
        p = []
        path, cost= get_path(goal_state.father, p)
        draw_map(my_map, path)
        print (f'The algorithm cost was: {cost}')
# Out:
# 188
# Solution found?  True
# The algorithm cost was: 33
# 175
# Solution found?  True
# The algorithm cost was: 85
# 231
# Solution found?  True
# The algorithm cost was: 123

# %% [markdown]
# Awnser: the order of the actions did alter the path taken by the dfs algorithm, obtaining the lowest cost of 71 with the action order of Left, Up, Down, Right. The change occured because the DFS algorithm is complete but not optimal.

# %% [markdown]
# 3. Does it happen the same thing when you change the order of actions for BFS (hint: to answer this calculate the cost of the path and experiment with diferent order for the actions)? Experiment, show your results and discuss.

# %%
#BFS
for actions in list_of_actions:
    my_map, start, goal = read_map_file()
    found, goal_state = bfs(start, goal, actions, my_map)
    my_map[start[1]][start[0]] = 1
    print('Solution found? ', found)
    if found:
        p = []
        path, cost= get_path(goal_state.father, p)
        draw_map(my_map, path)
        print (f'The algorithm cost was: {cost}')
# Out:
# Solution found?  True
# The algorithm cost was: 29
# Solution found?  True
# The algorithm cost was: 29
# Solution found?  True
# The algorithm cost was: 29

# %% [markdown]
# Awnser: the order of the actions did NOT alter the path taken by the bfs this is due to bfs being an optimal algorithm, meaning that it will find the path with the lowest cost everytime.

# %% [markdown]
# 4. Did BFS or DFS find the optimal path? What is the cost of it? Give some examples

# %%
# your code here

# %% [markdown]
# The BFS Algorithm found the optimal path in every example we ran,

# %% [markdown]
# 5. Execute BFS and DFS for the map2.txt file. Which one finds a better path? Which one would you choose for the path-finding problem?

# %%
actions = ['U', 'D', 'L', 'R']

my_map, start, goal = read_map_file( file_name = "map2.txt")
found, goal_state = bfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
print (f'The algorithm cost was: {cost}')

my_map, start, goal = read_map_file( file_name = "map2.txt")
found, goal_state = dfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
print (f'The algorithm cost was: {cost}')
# Out:
# Solution found?  True
# The algorithm cost was: 26
# 99
# Solution found?  True
# The algorithm cost was: 60

# %% [markdown]
# Personally we would choose the BFS algorithm for this case due to the easiness it has to find the shortest path available.

# %% [markdown]
# ## Exercises Informed Search

# %% [markdown]
# 1. Let's suppose:
# - the agent can now go through trees and water.
# - the cost to go from one state to another is:
#     - empty spaces: 1
#     - trees: 3
#     - water: 5
#
# Solve the problem using A* using the Manhattan distance as a heuristic.
#
# You may use map3.txt and map4.txt here.

# %%
actions = ['U','D','R','L']
path_taken=[]

class State:
    def _init_(self):
        self.father = None
        self.value = None
        self.f = None
        self.g = None
        self.h = None
        
    def __lt__(self, other):
        return self.f < other.f

def get_path(state, path):
    if (hasattr(state, 'father')):
        path.append(state.value)
        get_path(state.father, path)
    return path, len(path)

    
def manhattan_distance(state, goal_state):
    a = state.value[0]
    b = state.value[1]
    return abs(a-goal_state[0]) + abs(b-goal_state[1])

def pythagoras_distance(state, goal_state):
    a = state.value[0]
    b = state.value[1]
    return math.floor(math.sqrt( math.pow(goal_state[0]-a, 2)   +  math.pow(goal_state[1]-b, 2) ) )



def cost_f(succesor): #porque state si solo usamos succesor
    if my_map[succesor.value[1]] [succesor.value[0]] == 0:
        return 1
    elif my_map[succesor.value[1]] [succesor.value[0]] == 2:
        return 3
    elif my_map[succesor.value[1]] [succesor.value[0]] == 3:
        return 5
    else: return 0
    
def goal_test(state, goal):
    if state == goal:return True
    return False


def tf(state, action, my_map):
    x = state.value[0]
    y = state.value[1]
    limit_x = len(my_map[0]) - 1
    limit_y = len(my_map) - 1
    next_state = None
    if action == 'L' and x > 0:
        next_state =  [x-1, y]
    elif action == 'R' and x < limit_x:
        next_state = [x+1, y]
    elif action == 'U' and y > 0:
        next_state = [x, y-1]
    elif action == 'D' and y < limit_y:
        next_state = [x, y+1]
    
    if next_state is not None:
        # verify if we already visited that state
        if my_map[next_state[1]][next_state[0]] != 5:
            new_state = State()
            new_state.father = state
            new_state.value = next_state
            return True, new_state
        
    return False, _

# %%
# your code here


def a_star_search_manhattan(start, goal, actions, my_map):
    open_states = PriorityQueue()    
    start_state = State()
    start_state.g = 0
    start_state.value = start
    my_list=[]
    
    open_states.put(start_state,0)
    closed_states = []
    
    while(not open_states.empty()):
        state = open_states.get()
        closed_states.append(state)
        my_map[state.value[1]][state.value[0]] = int(visited_char)
        if(goal_test(state.value, goal)):
            return True, state
        for a in actions:
            exists, successor = tf(state, a,    my_map)
            if not exists:
                continue
            if successor in closed_states:
                continue
            successor.h = manhattan_distance(successor,goal)
            successor.g = state.g + cost_f(successor)
            successor.f = successor.h + successor.g
            
            if successor in open_states.queue: #Tenemos que revisar el color de las casillas, el open y closed 
                index = my_list.index(successor) #State()
                if successor.g > open_states[state].g:
                    #se tendria que eliminar el duplicado del open
                    continue
            open_states.put(successor, successor.f)
    return False,_

# %%
# your code here


def a_star_search_pythagoras(start, goal, actions, my_map):
    open_states = PriorityQueue()    
    start_state = State()
    start_state.g = 0
    start_state.value = start
    my_list=[]
    
    open_states.put(start_state,0)
    closed_states = []
    
    while(not open_states.empty()):
        state = open_states.get()
        closed_states.append(state)
        my_map[state.value[1]][state.value[0]] = int(visited_char)
        if(goal_test(state.value, goal)):
            return True, state
        for a in actions:
            exists, successor = tf(state, a,    my_map)
            if not exists:
                continue
            if successor in closed_states:
                continue
            successor.h = pythagoras_distance(successor,goal)
            successor.g = state.g + cost_f(successor)
            successor.f = successor.h + successor.g
            
            if successor in open_states.queue: #Tenemos que revisar el color de las casillas, el open y closed 
                index = my_list.index(successor) #State()
                if successor.g > open_states[state].g:
                    #se tendria que eliminar el duplicado del open
                    continue
            open_states.put(successor, successor.f)
    return False,_

# %%
my_map, start, goal = read_map_file(file_name='map4.txt')
found, goal_state = a_star_search_manhattan(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
my_map[goal_state.value[1]][goal_state.value[0]] = 1 # restore start position  color
print('Solution found? ', found)
if found:
    p =[]
    path , cost= get_path(goal_state.father, p)
    draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map4.txt')
found, goal_state = a_star_search_pythagoras(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
my_map[goal_state.value[1]][goal_state.value[0]] = 1 # restore start position  color
print('Solution found? ', found)
if found:
    p =[]
    path , cost= get_path(goal_state.father, p)
    draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
#a = [10,2]
#b = [24,23]
#math.floor(math.sqrt( math.pow(a[0]-a[1], 2)   +  math.pow(b[0]-b[1], 2) ) )

# %% [markdown]
# 2. How many states expands A*?

# %% [markdown]
# 3. Is A* optimal and complete for this case? Justify your answers

# %%
# your answer here

# %% [markdown]
# 4. Create an empty map of 21x21 put the start position in one extreme, the goal position in another and execute BFS and A* in this map and compare both algorithms. Answer some questions such as: what is the states space? which one expands/visits less states? which one does a better job?

# %%
# your answer here

# %%
my_map, start, goal = read_map_file(file_name='map21empty.txt')
found, goal_state = dfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# 840
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21empty.txt')
found, goal_state = a_star_search_pythagoras(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21a.txt')
found, goal_state = a_star_search_manhattan(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21empty.txt')
found, goal_state = bfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1# restore start position  color
print('Solution found? ', found)
p = []
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qj/2jp6hl0n1jddh5lltpjmdkmc0000gn/T/ipykernel_87275/3000891242.py in <module>
#       1 my_map, start, goal = read_map_file(file_name='map21.txt')
# ----> 2 found, goal_state = bfs(start, goal, actions, my_map)
#       3 my_map[start[1]][start[0]] = 1# restore start position  color
#       4 print('Solution found? ', found)
#       5 p = []
#
# /var/folders/qj/2jp6hl0n1jddh5lltpjmdkmc0000gn/T/ipykernel_87275/2955291697.py in bfs(start, goal, actions, my_map)
#      59             succesor, new_state = tf(state, action, my_map)
#      60             if (succesor == True):
# ---> 61                 open_states.put(new_state)
#      62
#      63     return False, _
#
# ~/opt/anaconda3/lib/python3.9/queue.py in put(self, item, block, timeout)
#     131         is ignored in that case).
#     132         '''
# --> 133         with self.not_full:
#     134             if self.maxsize > 0:
#     135                 if not block:
#
# ~/opt/anaconda3/lib/python3.9/threading.py in __enter__(self)
#     254         self._waiters.clear()
#     255
# --> 256     def __enter__(self):
#     257         return self._lock.__enter__()
#     258
#
# KeyboardInterrupt:

# %% [markdown]
# ## mapa de prueba

# %%
my_map, start, goal = read_map_file(file_name='map21a.txt')
found, goal_state = dfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# 803
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21a.txt')
found, goal_state = a_star_search_manhattan(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21a.txt')
found, goal_state = a_star_search_pythagoras(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21a.txt')
found, goal_state = bfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21b.txt')
found, goal_state = dfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# 803
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21b.txt')
found, goal_state = a_star_search_manhattan(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21b.txt')
found, goal_state = a_star_search_pythagoras(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
# Out:
# Solution found?  True

# %%
my_map, start, goal = read_map_file(file_name='map21b.txt')
found, goal_state = bfs(start, goal, actions, my_map)
my_map[start[1]][start[0]] = 1 # restore start position  color
print('Solution found? ', found)
p =[]
path, cost = get_path(goal_state.father, p)
draw_map(my_map, path)
